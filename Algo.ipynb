# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('mel_books_kz.xls')
df3 = pd.DataFrame(data, columns= ['Book name','Price','Category'],index=[0, 1, 2])

data1 = pd.read_excel('Data.xls')
df1 = pd.DataFrame(data1, columns= ['Book name','Price','Category'],index=[3, 4, 5])


data2 = pd.read_excel('meloman_books_children.xls')
df2 = pd.DataFrame(data2, columns= ['Book name','Price','Category'],index=[6, 7, 8])


df = [df2, df3]
df = pd.concat(df)

df_total = [df1,df2, df3]
df_total = pd.concat(df_total)

print (df_total)
# Out:
#                                            Book name   Price  \
# 3       Кинг С.: Мертвая зона. Король на все времена  1 550
# 4              Кинг С.: Кэрри. Эксклюзивная классика  1 370
# 5             Кинг С.: Сияние. Эксклюзивная классика  1 750
# 6         Брисси П.: MINECRAFT. Охота за сокровищами    2360
# 7  Картер Э.: Тайна дома Винтерборнов. Ключ от пр...    2760
# 8    Валентино С.: Леди Тремейн. История злой мачехи    2530
# 0  Даулет Арманович: 1 000 000 $ в инвестициях на...    2990
# 1                       Бекжігітова К.: Өмірдің мәні    3990
# 2                     Соқпақбаев Б.: Менің атым Қожа    1400
#
#                                             Category
# 3                          Художественная литература
# 4                          Художественная литература
# 5                          Художественная литература
# 6                               Книги для подростков
# 7                               Книги для подростков
# ...

# %% [markdown]
# # Price of categories
#
# #### What is the most expensive category?
# #### What is the most cheapest category?
#
#
# #### We can see that the genre "Psychology"  is the most expensive

# %%
df_lit = data[data['Category'] == 'Деловая литература']
df_InKaz = data[data['Category'] == 'Всемирнаяя классика на казахском языке']
df_forChild = data[data['Category'] == 'Детская познавательная литература']
df_forChildH = data[data['Category'] == 'Детская художественная литература на казахском языке']
df_learnK = data[data['Category'] == 'Изучение казахского языка, словари']
df_classicK = data[data['Category'] == 'Казахстанская классика']
df_culture = data[data['Category'] == 'Культура и Искусство ']
df_modern = data[data['Category'] == 'Современная казахстанская проза']
df_noclas = data[data['Category'] == 'Нехудожественная литература']
df_psych = data[data['Category'] == 'Психология, педагогика']
df2_mean = df2['Price'].mean()
df3_mean = df3['Price'].mean()

df_lit_median = df_lit['Price'].mean()
df_lit_max = df_lit['Price'].max()
df_lit_min= df_lit['Price'].min()


df_InKaz_median = df_InKaz['Price'].mean()
df_InKaz_max = df_InKaz['Price'].max()
df_InKaz_min= df_InKaz['Price'].min()


df_forChild_median = df_forChild['Price'].mean()
df_forChild_max = df_forChild['Price'].max()
df_forChild_min= df_forChild['Price'].min()


df_learnK_median = df_learnK['Price'].mean()
df_learnK_max = df_learnK['Price'].max()
df_learnK_min= df_learnK['Price'].min()


df_classicK

df_noclas_median = df_noclas['Price'].mean()
df_noclas_max = df_noclas['Price'].max()
df_noclas_min= df_noclas['Price'].min()


df_psych_median = df_psych['Price'].mean()
df_psych_max = df_psych['Price'].max()
df_psych_min= df_psych['Price'].min()

df2_median = df2['Price'].mean()
df2_max = df2['Price'].max()
df2_min= df2['Price'].min()


labels = ['Деловая литература', 'Всемирнаяя классика на казахском языке', 'Психология, педагогика','Нехудожественная литература','Казахстанская классика','Книги для подростков']

mean = [3306, 2765, 3535, 2895, 2323,2550]
max_p = [4000, 3590, 5800, 3500, 4200,2760]
min_p = [2550, 2390, 1500,2290, 850, 2360]


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 0.2, max_p, width, label='Max price')
rects2 = ax.bar(x , min_p, width, label='Min price')
rects3 = ax.bar(x + 0.2, mean, width, label='Avg price')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Price')
ax.set_title('Prices')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation='vertical')
ax.legend()


fig.tight_layout()
plt.rcParams["figure.figsize"] = (15,10)

plt.show()

print('The most expensive category is Psychology: 5800')
print('The most cheapest category is Kazakh classic: 850')
# Out:
# The most expensive category is Psychology: 5800
# The most cheapest category is Kazakh classic: 850

# %% [markdown]
# # Popular books in meloman.kz

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Деловая литература', 'Всемирнаяя классика на казахском языке', 'Детская познавательная литература','Детская художественная литература на казахском языке','Изучение казахского языка, словари','Казахстанская классика','Культура и Искусство ','Современная казахстанская проза','Нехудожественная литература','Психология, педагогика'
sizes = [105,84,21,315,21,273,84,210,42,189]

fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct='%0.1f%%',
         startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.rcParams["figure.figsize"] = (7,7)
plt.show()

df_lit = data[data['Category'] == 'Деловая литература']
print('Деловая литература : {}'.format(df_lit['Category'].count()))

df_InKaz = data[data['Category'] == 'Всемирнаяя классика на казахском языке']
print('Всемирнаяя классика на казахском языке : {}'.format(df_InKaz['Category'].count()))

df_forChild = data[data['Category'] == 'Детская познавательная литература']
print('Детская познавательная литература : {}'.format(df_forChild['Category'].count()))

df_forChildH = data[data['Category'] == 'Детская художественная литература на казахском языке']
print('Детская художественная литература на казахском языке : {}'.format(df_forChildH['Category'].count()))

df_learnK = data[data['Category'] == 'Изучение казахского языка, словари']
print('Изучение казахского языка, словари : {}'.format(df_learnK['Category'].count()))

df_classicK = data[data['Category'] == 'Казахстанская классика']
print('Казахстанская классика : {}'.format(df_classicK['Category'].count()))

df_culture = data[data['Category'] == 'Культура и Искусство ']
print('Культура и Искусство : {}'.format(df_culture['Category'].count()))

df_modern = data[data['Category'] == 'Современная казахстанская проза']
print('Современная казахстанская проза : {}'.format(df_modern['Category'].count()))

df_noclas = data[data['Category'] == 'Нехудожественная литература']
print('Нехудожественная литература : {}'.format(df_noclas['Category'].count()))

df_psych = data[data['Category'] == 'Психология, педагогика']
print('Психология, педагогика : {}'.format(df_psych['Category'].count()))
# Out:
# Деловая литература : 5
# Всемирнаяя классика на казахском языке : 4
# Детская познавательная литература : 1
# Детская художественная литература на казахском языке : 15
# Изучение казахского языка, словари : 1
# Казахстанская классика : 13
# Культура и Искусство : 4
# Современная казахстанская проза : 10
# Нехудожественная литература : 2
# Психология, педагогика : 9

# %% [markdown]
# # Basically what books are being sold?

# %%
df = pd.DataFrame({'Amount': [105,84,21,315,21,273,84,210,42,189,2000,7680]},
                   
                  index=['Деловая литература', 'Всемирнаяя классика на казахском языке', 'Детская познавательная литература',
                         'Детская художественная литература на казахском языке','Изучение казахского языка, словари',
                         'Казахстанская классика','Культура и Искусство ','Современная казахстанская проза','Нехудожественная литература',
                         'Психология, педагогика','Книги для подростков','Художественная литература'])
plot = df.plot.pie(y='Amount', figsize=(10, 10))

print('They mainly sell the fiction category \n')

print('Художественная литература : {}'.format(data1['Category'].count()))
print('Книги для подростков : {}'.format(data2['Category'].count()))
df_forChildH = data[data['Category'] == 'Детская художественная литература на казахском языке']
print('Детская художественная литература на казахском языке : {}'.format(df_forChildH['Category'].count()))
# Out:
# They mainly sell the fiction category
#
# Художественная литература : 7680
# Книги для подростков : 2000
# Детская художественная литература на казахском языке : 15
