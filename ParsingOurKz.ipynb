# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
booksList = []
def getBooks(tag, page):
    url = 'https://www.meloman.kz/books/our-kazakhstan/?p=2'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, "html.parser")
    books_kz = soup.findAll('li', class_='item product product-item')
    for item in books_kz:
        books = {
        'Book name': item.find('a', class_= 'product-item-link').text,
        'Price': item.find('span', class_='price-wrapper')['data-price-amount'],
        'Price with discount': item.find('span', class_= 'special-price'),
        'Discount': item.find('span', class_='astrio-overlay-discount-percent__percent'),
        'Avalability': item.find('span', class_='product-item__stock-label').text,
        'Category': item.find('a', class_='product-item-link')['data-category']
        }
        booksList.append(books)
    return
for x in range(1,22):
    getBooks('books-for-kz', x)
    print(len(booksList))
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100

# %%
df = pd.DataFrame(booksList)

# %%
df
# Out:
#                                             Book name Price  \
# 0      Бексұлтан Қазыбек: ҚазақMan Batyr. Шығарылым 3   990
# 1                Роулиң Ж.: Хәрри Поттер мен От сауыт  6450
# 2                Мұртаза Ш.: Сүдігерде изен ызыңдайды  1090
# 3     Ертайұлы Е.: Жұбайыңның жүрегін жаралама//жаула  3500
# 4                            Мақатаев М.: Өмір - өзен  1450
# ...                                               ...   ...
# 2095                      Мұқанов С.: Мөлдір махаббат  3920
# 2096    Кекильбаев А.: Конец легенды. Роман и повести  2450
# 2097        Аладдин. Сказки Disney на казахском языке  1990
# 2098                      Су перісі II: теңізге оралу  1990
# 2099                                Ханша мен құрбақа  1990
#
#      Price with discount Discount Avalability  \
# 0                   None     None   На складе
# 1                   None     None   На складе
# 2                   None     None   На складе
# 3                   None     None   На складе
# 4                   None     None   На складе
# ...                  ...      ...         ...
# 2095                None     None   На складе
# 2096                None     None   На складе
# 2097                None     None   На складе
# 2098                None     None   На складе
# 2099                None     None   На складе
#
#                                                Category
# 0     Книги/Наш Казахстан/Детская художественная лит...
# 1     Книги/Наш Казахстан/Детская художественная лит...
# 2     Книги/Наш Казахстан/Современная казахстанская ...
# 3            Книги/Наш Казахстан/Психология, педагогика
# 4            Книги/Наш Казахстан/Казахстанская классика
# ...                                                 ...
# 2095         Книги/Наш Казахстан/Казахстанская классика
# 2096  Книги/Наш Казахстан/Современная казахстанская ...
# 2097                        Книги/Наш Казахстан/Малышам
# 2098                        Книги/Наш Казахстан/Малышам
# 2099                        Книги/Наш Казахстан/Малышам
#
# [2100 rows x 6 columns]

# %%
df.to_csv('meloman_books_kz2.csv', index = True)
